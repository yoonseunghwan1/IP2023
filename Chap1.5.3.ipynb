# %% [markdown]
# ## Chap1.5.3 Shi-Tomasi Corner Detector & Good Features to Track

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('depositphotos_13473158-stock-photo-woman-hand.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
corners = cv2.goodFeaturesToTrack(gray,25,0.01,10)
corners = np.int0(corners)
for i in corners:
    x,y = i.ravel()
    cv2.circle(img,(x,y),3,255,-1)
plt.imshow(img),plt.show()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_30796\3872821107.py:7: DeprecationWarning: `np.int0` is a deprecated alias for `np.intp`.  (Deprecated NumPy 1.24)
#   corners = np.int0(corners)
# (<matplotlib.image.AxesImage at 0x169c0679c40>, None)
